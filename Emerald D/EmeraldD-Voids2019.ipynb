# %%
import pandas as pd 
import os

# %%
data = pd.read_csv("EmeraldDesertRV-Voids 4th Qtr.csv")

# %%
data.head()
# Out:
#        Sunland RV Resort Emerald Desert Unnamed: 1  Unnamed: 2 Unnamed: 3  \
# 0                          Void Reasons        NaN         NaN        NaN
# 1  Date: From 1 Oct 2019 to 31 Dec 2019        NaN         NaN        NaN
# 2                                   NaN        NaN         NaN        NaN
# 3                                   NaN   Property  Account No   Trans No
# 4                                   NaN        NaN         NaN        NaN
#
#   Unnamed: 4 Unnamed: 5               Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 0        NaN        NaN                      NaN        NaN        NaN
# 1        NaN        NaN                      NaN        NaN        NaN
# 2        NaN        NaN                      NaN        NaN        NaN
# 3     Res No       Date  Transaction Description     Reason    GL Code
# 4        NaN        NaN                      NaN        NaN        NaN
#
#   Unnamed: 9 Unnamed: 10 Unnamed: 11
# 0        NaN         NaN         NaN
# ...

# %%
data1 = data.rename(columns={"Sunland RV Resort Emerald Desert": "Sunland", "Unnamed: 1": "Property", "Unnamed: 2": "Account No", "Unnamed: 3": "Trans No", "Unnamed: 4": "Res No", "Unnamed: 5": "Date", "Unnamed: 6": "Transaction Description", "Unnamed: 7": "Reason", "Unnamed: 8": "GL Code", "Unnamed: 9": "User Name", "Unnamed: 10": "Blank", "Unnamed: 11": "Amount"})
data1.head()
# Out:
#                                 Sunland  Property  Account No  Trans No  \
# 0                          Void Reasons       NaN         NaN       NaN
# 1  Date: From 1 Oct 2019 to 31 Dec 2019       NaN         NaN       NaN
# 2                                   NaN       NaN         NaN       NaN
# 3                                   NaN  Property  Account No  Trans No
# 4                                   NaN       NaN         NaN       NaN
#
#    Res No  Date  Transaction Description  Reason  GL Code  User Name Blank  \
# 0     NaN   NaN                      NaN     NaN      NaN        NaN   NaN
# 1     NaN   NaN                      NaN     NaN      NaN        NaN   NaN
# 2     NaN   NaN                      NaN     NaN      NaN        NaN   NaN
# 3  Res No  Date  Transaction Description  Reason  GL Code  User Name   NaN
# 4     NaN   NaN                      NaN     NaN      NaN        NaN   NaN
#
#    Amount
# 0     NaN
# 1     NaN
# 2     NaN
# 3  Amount
# 4     NaN

# %%
data2 = data1.drop(columns=['Sunland', 'Blank'])
data2.head()
# Out:
#    Property  Account No  Trans No  Res No  Date  Transaction Description  \
# 0       NaN         NaN       NaN     NaN   NaN                      NaN
# 1       NaN         NaN       NaN     NaN   NaN                      NaN
# 2       NaN         NaN       NaN     NaN   NaN                      NaN
# 3  Property  Account No  Trans No  Res No  Date  Transaction Description
# 4       NaN         NaN       NaN     NaN   NaN                      NaN
#
#    Reason  GL Code  User Name  Amount
# 0     NaN      NaN        NaN     NaN
# 1     NaN      NaN        NaN     NaN
# 2     NaN      NaN        NaN     NaN
# 3  Reason  GL Code  User Name  Amount
# 4     NaN      NaN        NaN     NaN

# %%
data3 = data2.dropna()
data3.head()
# Out:
#                            Property  Account No  Trans No  Res No      Date  \
# 3                          Property  Account No  Trans No  Res No      Date
# 5  Sunland RV Resort Emerald Desert      384765  16230639  227792  1-Oct-19
# 6  Sunland RV Resort Emerald Desert      368679  15984798  215820  1-Oct-19
# 7  Sunland RV Resort Emerald Desert      384766  16230824  227793  1-Oct-19
# 8  Sunland RV Resort Emerald Desert      381523  16042331  225307  1-Oct-19
#
#                      Transaction Description                 Reason  \
# 3                    Transaction Description                 Reason
# 5  Void: 07-ED Parking/Storage - (01-Oct-19)  Cancelled Reservation
# 6      Void: 02-ED Weekly Rate - (01-Oct-19)  Cancelled Reservation
# 7  Void: 07-ED Parking/Storage - (01-Oct-19)  Cancelled Reservation
# 8                    Void: 45 Ft. RV Storage  Cancelled Reservation
#
#       GL Code  User Name  Amount
# 3     GL Code  User Name  Amount
# ...

# %%
data4 = data3.drop(3)
data4.head()
# Out:
#                            Property Account No  Trans No  Res No      Date  \
# 5  Sunland RV Resort Emerald Desert     384765  16230639  227792  1-Oct-19
# 6  Sunland RV Resort Emerald Desert     368679  15984798  215820  1-Oct-19
# 7  Sunland RV Resort Emerald Desert     384766  16230824  227793  1-Oct-19
# 8  Sunland RV Resort Emerald Desert     381523  16042331  225307  1-Oct-19
# 9  Sunland RV Resort Emerald Desert     381523  16042199  225307  1-Oct-19
#
#                      Transaction Description                 Reason  \
# 5  Void: 07-ED Parking/Storage - (01-Oct-19)  Cancelled Reservation
# 6      Void: 02-ED Weekly Rate - (01-Oct-19)  Cancelled Reservation
# 7  Void: 07-ED Parking/Storage - (01-Oct-19)  Cancelled Reservation
# 8                    Void: 45 Ft. RV Storage  Cancelled Reservation
# 9  Void: 07-ED Parking/Storage - (01-Oct-19)  Cancelled Reservation
#
#       GL Code User Name Amount
# 5     PARKING    Amanda      0
# 6  Lot-Weekly    Amanda     62
# ...

# %%
data5 = data4.drop_duplicates()
data5.head()
# Out:
#                            Property Account No  Trans No  Res No      Date  \
# 5  Sunland RV Resort Emerald Desert     384765  16230639  227792  1-Oct-19
# 6  Sunland RV Resort Emerald Desert     368679  15984798  215820  1-Oct-19
# 7  Sunland RV Resort Emerald Desert     384766  16230824  227793  1-Oct-19
# 8  Sunland RV Resort Emerald Desert     381523  16042331  225307  1-Oct-19
# 9  Sunland RV Resort Emerald Desert     381523  16042199  225307  1-Oct-19
#
#                      Transaction Description                 Reason  \
# 5  Void: 07-ED Parking/Storage - (01-Oct-19)  Cancelled Reservation
# 6      Void: 02-ED Weekly Rate - (01-Oct-19)  Cancelled Reservation
# 7  Void: 07-ED Parking/Storage - (01-Oct-19)  Cancelled Reservation
# 8                    Void: 45 Ft. RV Storage  Cancelled Reservation
# 9  Void: 07-ED Parking/Storage - (01-Oct-19)  Cancelled Reservation
#
#       GL Code User Name Amount
# 5     PARKING    Amanda      0
# 6  Lot-Weekly    Amanda     62
# ...

# %%
data5.to_csv("EmeraldDesertRV-Voids 4th Qtr_modified.csv", index=False, header=True)
